# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = spark.read.table("databricks_catalog.bronze.regions")

# %%
df.display()

# %%
df = df.drop("_rescued_data")

# %%
 df.createOrReplaceTempView("reg")

# %%
# %sql
select * from reg

# %%
df.display()

# %%
df2 = df.filter(col('region')=="West")

# %%
df2.display()

# %%
df.write.format("delta").mode("overwrite").save("abfss://silver@databricksetecharif.dfs.core.windows.net/regions")

# %%
dbutils.widgets.text("file_name","")

# %%
param = dbutils.widgets.get("file_name")

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_catalog.silver.regions_silver
USING DELTA
LOCATION 'abfss://silver@databricksetecharif.dfs.core.windows.net/regions'

# %%
# %sql
select * from databricks_catalog.silver.regions_silver
